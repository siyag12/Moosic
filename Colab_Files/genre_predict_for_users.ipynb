# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Reading Files

# %%
labeled_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/Final_Submission/5k_dataset.csv')
user_1_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_1.csv')
user_2_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_2.csv')
user_3_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_3.csv')
user_4_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_4.csv')
user_5_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_5.csv')
user_6_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_6.csv')
user_7_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_7.csv')
user_8_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_8.csv')
user_9_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_9.csv')
user_10_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_10.csv')
user_11_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_11.csv')
user_12_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_12.csv')
user_13_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_13.csv')
user_14_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_14.csv')
user_15_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_15.csv')
user_16_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_16.csv')
user_17_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_17.csv')
user_18_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_18.csv')
user_19_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_19.csv')
user_20_df = pd.read_csv('drive/MyDrive/ML_Project_Sem5/User_Playlist_data/user_playlist_20.csv')

# %%
genre = labeled_df['Genre']

# %%
user_1_df.sort_index(axis=1, inplace = True)
user_1_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_1_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_2_df.sort_index(axis=1, inplace = True)
user_2_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_2_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_3_df.sort_index(axis=1, inplace = True)
user_3_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_3_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_4_df.sort_index(axis=1, inplace = True)
user_4_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_4_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_5_df.sort_index(axis=1, inplace = True)
user_5_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_5_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_6_df.sort_index(axis=1, inplace = True)
user_6_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_6_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_7_df.sort_index(axis=1, inplace = True)
user_7_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_7_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_8_df.sort_index(axis=1, inplace = True)
user_8_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_8_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_9_df.sort_index(axis=1, inplace = True)
user_9_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_9_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_10_df.sort_index(axis=1, inplace = True)
user_10_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_10_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_11_df.sort_index(axis=1, inplace = True)
user_11_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_11_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_12_df.sort_index(axis=1, inplace = True)
user_12_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_12_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_13_df.sort_index(axis=1, inplace = True)
user_13_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_13_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_14_df.sort_index(axis=1, inplace = True)
user_14_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_14_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_15_df.sort_index(axis=1, inplace = True)
user_15_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_15_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_16_df.sort_index(axis=1, inplace = True)
user_16_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_16_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_17_df.sort_index(axis=1, inplace = True)
user_17_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_17_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_18_df.sort_index(axis=1, inplace = True)
user_18_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_18_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_19_df.sort_index(axis=1, inplace = True)
user_19_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_19_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

user_20_df.sort_index(axis=1, inplace = True)
user_20_df.drop(['Unnamed: 0', 'id', 'key', 'mode','time_signature'], axis=1, inplace = True)
user_20_df.set_axis(['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'], axis=1, inplace=True)

# %%
labeled_df.sort_index(axis=1, inplace = True)
labeled_df.drop(['Unnamed: 0', 'Album Name','Artist Name','Genre','Key','Mode','Popularity','Release Date','Sno','Song Duration','Song ID','Song Name','Time Signature'], axis=1, inplace = True)

# %%
scaler = MinMaxScaler()
features2 = scaler.fit_transform(labeled_df)
labeled_df = pd.DataFrame(features2, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])

# %%
label = scaler.transform(user_1_df)
user_1_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_2_df)
user_2_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_3_df)
user_3_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_4_df)
user_4_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_5_df)
user_5_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_6_df)
user_6_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_7_df)
user_7_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_8_df)
user_8_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_9_df)
user_9_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_10_df)
user_10_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_11_df)
user_11_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_12_df)
user_12_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_13_df)
user_13_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_14_df)
user_14_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_15_df)
user_15_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_16_df)
user_16_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_17_df)
user_17_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_18_df)
user_18_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_19_df)
user_19_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])
label = scaler.transform(user_20_df)
user_20_df = pd.DataFrame(label, columns = ['Acousticness', 'Dancebility', 'Energy', 'Instrumentalness','Liveliness', 'Loudness', 'Speechiness', 'Tempo', 'Valence'])

# %%
X_train, X_test, y_train, y_test = train_test_split(labeled_df, genre, test_size=0.15, random_state=42)

# %% [markdown]
# #RUNNING CLASSIFICATION MODELS

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(max_iter=200).fit(X_train, y_train)
y_pred = clf.predict(X_test)

misclasified = np.sum(y_pred != y_test)
acc =  1 - misclasified/y_pred.shape

print("accuracy: ", acc*100, "%")
# Out:
# accuracy:  [70.8] %

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#  death-metal     0.7786    0.7786    0.7786       140
#          edm     0.6306    0.6266    0.6286       158
#        happy     0.7758    0.7529    0.7642       170
#         rock     0.5742    0.6268    0.5993       142
#          sad     0.7970    0.7571    0.7766       140
#
#     accuracy                         0.7080       750
#    macro avg     0.7112    0.7084    0.7094       750
# weighted avg     0.7115    0.7080    0.7094       750

# %%
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB().fit(X_train, y_train)
y_pred = clf.predict(X_test)

misclasified = np.sum(y_pred != y_test)
acc =  1 - misclasified/y_pred.shape

print("accuracy: ", acc*100, "%")
# Out:
# accuracy:  [54.8] %

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#  death-metal     0.6105    0.8286    0.7030       140
#          edm     0.4156    0.4051    0.4103       158
#        happy     0.6818    0.3529    0.4651       170
#         rock     0.4184    0.5775    0.4852       142
#          sad     0.7295    0.6357    0.6794       140
#
#     accuracy                         0.5480       750
#    macro avg     0.5712    0.5600    0.5486       750
# weighted avg     0.5714    0.5480    0.5418       750

# %%
from sklearn.linear_model import SGDClassifier

clf = SGDClassifier().fit(X_train, y_train)

y_pred = clf.predict(X_test)

misclasified = np.sum(y_pred != y_test)
acc =  1 - misclasified/y_pred.shape

print("accuracy: ", acc*100, "%")
# Out:
# accuracy:  [65.73333333] %

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#  death-metal     0.7209    0.8857    0.7949       140
#          edm     0.7317    0.1899    0.3015       158
#        happy     0.7022    0.7353    0.7184       170
#         rock     0.5024    0.7394    0.5983       142
#          sad     0.7267    0.7786    0.7517       140
#
#     accuracy                         0.6573       750
#    macro avg     0.6768    0.6658    0.6330       750
# weighted avg     0.6787    0.6573    0.6283       750

# %%
from sklearn.neighbors import KNeighborsClassifier

clf = KNeighborsClassifier().fit(X_train, y_train)

y_pred = clf.predict(X_test)

misclasified = np.sum(y_pred != y_test)
acc =  1 - misclasified/y_pred.shape

print("accuracy: ", acc*100, "%")
# Out:
# accuracy:  [71.2] %

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#  death-metal     0.7246    0.8643    0.7883       140
#          edm     0.6223    0.7405    0.6763       158
#        happy     0.8671    0.7294    0.7923       170
#         rock     0.5748    0.5141    0.5428       142
#          sad     0.7920    0.7071    0.7472       140
#
#     accuracy                         0.7120       750
#    macro avg     0.7162    0.7111    0.7094       750
# weighted avg     0.7196    0.7120    0.7114       750

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier().fit(X_train, y_train)

y_pred = clf.predict(X_test)

misclasified = np.sum(y_pred != y_test)
acc =  1 - misclasified/y_pred.shape

print("accuracy: ", acc*100, "%")
# Out:
# accuracy:  [69.86666667] %

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#  death-metal     0.8088    0.7857    0.7971       140
#          edm     0.6023    0.6519    0.6261       158
#        happy     0.8095    0.8000    0.8047       170
#         rock     0.5588    0.5352    0.5468       142
#          sad     0.7122    0.7071    0.7097       140
#
#     accuracy                         0.6987       750
#    macro avg     0.6983    0.6960    0.6969       750
# weighted avg     0.7001    0.6987    0.6991       750

# %%
from sklearn.svm import SVC

clf = SVC().fit(X_train, y_train)

y_pred = clf.predict(X_test)

misclasified = np.sum(y_pred != y_test)
acc =  1 - misclasified/y_pred.shape

print("accuracy: ", acc*100, "%")
# Out:
# accuracy:  [71.86666667] %

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#  death-metal     0.7733    0.8286    0.8000       140
#          edm     0.6220    0.6456    0.6335       158
#        happy     0.8098    0.7765    0.7928       170
#         rock     0.5944    0.5986    0.5965       142
#          sad     0.8000    0.7429    0.7704       140
#
#     accuracy                         0.7187       750
#    macro avg     0.7199    0.7184    0.7186       750
# weighted avg     0.7208    0.7187    0.7192       750

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier().fit(X_train, y_train)

y_pred = clf.predict(X_test)

misclasified = np.sum(y_pred != y_test)
acc =  1 - misclasified/y_pred.shape

print("accuracy: ", acc*100, "%")
# Out:
# accuracy:  [80.93333333] %

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#  death-metal     0.8311    0.8786    0.8542       140
#          edm     0.8054    0.7595    0.7818       158
#        happy     0.9119    0.8529    0.8815       170
#         rock     0.6831    0.6831    0.6831       142
#          sad     0.8026    0.8714    0.8356       140
#
#     accuracy                         0.8093       750
#    macro avg     0.8068    0.8091    0.8072       750
# weighted avg     0.8107    0.8093    0.8092       750

# %%
from sklearn.neural_network import MLPClassifier

clf = MLPClassifier(max_iter=700).fit(X_train, y_train)

y_pred = clf.predict(X_test)

misclasified = np.sum(y_pred != y_test)
acc =  1 - misclasified/y_pred.shape

print("accuracy: ", acc*100, "%")
# Out:
# accuracy:  [75.46666667] %

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#  death-metal     0.8322    0.8500    0.8410       140
#          edm     0.6913    0.6519    0.6710       158
#        happy     0.8424    0.8176    0.8299       170
#         rock     0.6301    0.6479    0.6389       142
#          sad     0.7687    0.8071    0.7875       140
#
#     accuracy                         0.7547       750
#    macro avg     0.7529    0.7549    0.7536       750
# weighted avg     0.7547    0.7547    0.7544       750

# %% [markdown]
# #Grid Search CV

# %% [markdown]
# ##Random Forest

# %%
rf = RandomForestClassifier(random_state = 0)
params = {'n_estimators': [120,160,190],
          'criterion': ['gini','entropy'],
          'max_features':['sqrt', 'log2'] }
gcv = GridSearchCV(rf,params)
gcv.fit(labeled_df, genre)

# %%
print(gcv.best_estimator_)
print(gcv.best_score_)

# %%
d = gcv.cv_results_
print(d)

# %%
import csv
with open('rf.csv','w') as f:
  for key in d.keys():
    f.write("%s,%s\n"%(key,d[key]))

# %% [markdown]
# ###Gini

# %%
rf1 = RandomForestClassifier(random_state = 0,criterion = 'gini')
params = {'n_estimators': [120,160,190],
          'max_features':['sqrt', 'log2'] }
gcv11 = GridSearchCV(rf1,params)
gcv11.fit(labeled_df, genre)
print('best estimator',gcv11.best_estimator_)
print('best score',gcv11.best_score_)
d = gcv11.cv_results_
print(d)
import csv
with open('rf_gini.csv','w') as f:
  for key in d.keys():
    f.write("%s,%s\n"%(key,d[key]))

# %% [markdown]
# ###Entropy

# %%
rf2 = RandomForestClassifier(random_state = 0,criterion = 'entropy')
params = {'n_estimators': [120,160,190],
          'max_features':['sqrt', 'log2'] }
gcv12 = GridSearchCV(rf1,params)
gcv12.fit(labeled_df, genre)
print('best estimator',gcv12.best_estimator_)
print('best score',gcv12.best_score_)
d = gcv12.cv_results_
print(d)
import csv
with open('rf_entropy.csv','w') as f:
  for key in d.keys():
    f.write("%s,%s\n"%(key,d[key]))

# %% [markdown]
# ##MLP

# %%
mlp = MLPClassifier(random_state = 0, max_iter = 700)
params = {'solver': ['lbfgs', 'sgd', 'adam'],
          'activation': ['logistic', 'tanh', 'relu'],
          'learning_rate_init':[0.01,0.005,0.001],
          'alpha': [0.005,0.0001,0.001]}
gcv2 = GridSearchCV(mlp,params)
gcv2.fit(labeled_df, genre)
print('best estimator',gcv2.best_estimator_)
print('best score',gcv2.best_score_)
d = gcv2.cv_results_
print(d)
import csv
with open('mlp.csv','w') as f:
  for key in d.keys():
    f.write("%s,%s\n"%(key,d[key]))

# %% [markdown]
# #BEST MODEL

# %%
# !pip install yellowbrick

# %%
from yellowbrick.model_selection import learning_curve
from sklearn.ensemble import RandomForestClassifier

# %%
from yellowbrick.classifier import ROCAUC

def plot_ROC_curve(model, xtrain, ytrain, xtest, ytest):

    # Creating visualization with the readable labels
    visualizer = ROCAUC(model)
                                        
    # Fitting to the training data first then scoring with the test data                                    
    visualizer.fit(xtrain, ytrain)
    visualizer.score(xtest, ytest)
    visualizer.show()
    
    return visualizer

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(max_features='sqrt', n_estimators=160, random_state=0, criterion = 'gini').fit(X_train, y_train)

y_pred = clf.predict(X_test)
misclasified = np.sum(y_pred != y_test)
acc =  1 - misclasified/y_pred.shape
print("accuracy: ", acc*100, "%")
# Out:
# accuracy:  [80.66666667] %

# %%
vis_randomforest = plot_ROC_curve(clf, X_train, y_train, X_test, y_test)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

# %% [markdown]
# ##Prediction

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(max_features='sqrt', n_estimators=160, random_state=0, criterion = 'gini').fit(labeled_df, genre)

y_pred = clf.predict(labeled_df)
misclasified = np.sum(y_pred != genre)
acc =  1 - misclasified/y_pred.shape
print("accuracy: ", acc*100, "%")

genre_1 = clf.predict(user_1_df)
genre_2 = clf.predict(user_2_df)
genre_3 = clf.predict(user_3_df)
genre_4 = clf.predict(user_4_df)
genre_5 = clf.predict(user_5_df)
genre_6 = clf.predict(user_6_df)
genre_7 = clf.predict(user_7_df)
genre_8 = clf.predict(user_8_df)
genre_9 = clf.predict(user_9_df)
genre_10 = clf.predict(user_10_df)
genre_11 = clf.predict(user_11_df)
genre_12 = clf.predict(user_12_df)
genre_13 = clf.predict(user_13_df)
genre_14 = clf.predict(user_14_df)
genre_15 = clf.predict(user_15_df)
genre_16 = clf.predict(user_16_df)
genre_17 = clf.predict(user_17_df)
genre_18 = clf.predict(user_18_df)
genre_19 = clf.predict(user_19_df)
genre_20 = clf.predict(user_20_df)

# %%
sns.countplot(genre_1)

# %%
sns.countplot(genre_2)

# %%
sns.countplot(genre_3)

# %%
sns.countplot(genre_4)

# %%
sns.countplot(genre_5)

# %%
sns.countplot(genre_6)

# %%
sns.countplot(genre_7)

# %%
sns.countplot(genre_8)

# %%
sns.countplot(genre_9)

# %%
sns.countplot(genre_10)

# %%
sns.countplot(genre_11)

# %%
sns.countplot(genre_12)

# %%
sns.countplot(genre_13)

# %%
sns.countplot(genre_14)

# %%
sns.countplot(genre_15)

# %%
sns.countplot(genre_16)

# %%
sns.countplot(genre_17)

# %%
sns.countplot(genre_18)

# %%
sns.countplot(genre_19)

# %%
sns.countplot(genre_20)

# %%
playlist_data = pd.DataFrame(columns = ['Playlist', 'Total', 'happy', 'sad', 'edm', 'rock', 'death-metal', 'Genre'])
playlist_data

# %%
arr = [0]*8
arr[0] = 'playlist_20'
unique, counts = np.unique(genre_20, return_counts=True)
arr[1] = (counts.sum())
for j in range(len(unique)):
  idx = playlist_data.columns.get_loc(unique[j])
  arr[idx] = counts[j]

ind = np.argmax(counts)
arr[7] = unique[ind]

playlist_data.loc[len(playlist_data)] = arr
playlist_data

# %%
playlist_data.set_axis(['User ID', 'Playlist Size', 'Happy', 'Sad', 'Edm', 'Rock', 'Death-Metal', 'Fav Genre'], axis=1, inplace=True)

# %%
playlist_data.to_csv('drive/MyDrive/ML_Project_Sem5/'+"Users_with_fav_genre.csv", index=False, encoding='utf-8-sig')
